# %%
import pandas as pd
# Panda, Panda
# Panda, Panda, Panda, Panda, Panda
import numpy as np
# I got numpy in Atlanta

# %% [markdown]
# ## Random Forest to predict Crime

# %%
INC = pd.read_csv('Data/Incidents.csv')
INC.head()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  FID  Join_Count  TARGET_FID  Join_Cou_1  TARGET_F_1  \
# 0           0    0           1           0           1           1
# 1           1    1           1           1           1           2
# 2           2    2           1           2           0           3
# 3           3    3           1           3           0           4
# 4           4    4           1           4           0           5
#
#    incident_i  case_numbe              incident_d                  incident_t  \
# 0   787108492       59881  12/30/2016 01:49:00 PM          INFORMATION REPORT
# 1   787300346       59906  01/01/2017 01:00:00 AM          INFORMATION REPORT
# 2   787147954       59892  12/31/2016 02:12:00 AM  FAMILY OFFENSE-NO VIOLENCE
# 3   787174660       59898  12/31/2016 09:39:00 AM                    SPEEDING
# 4   762180594       54597  06/13/2016 06:07:00 PM  FAIL TO YIELD TURNING LEFT
#
#       ...     PRECIPITATIONIN EVENTS MEAN_VISIBILITYMILES  CityName  ZipCode2  \
# 0     ...                0.00    NaN                 10.0  DUNWOODY     30346
# 1     ...                 NaN    NaN                  NaN  DUNWOODY     30346
# 2     ...                0.17   Rain                  9.0  DUNWOODY     30338
# 3     ...                0.17   Rain                  9.0  DUNWOODY         0
# 4     ...                0.00    NaN                 10.0  DUNWOODY     30346
#
#    IncidentGroup2  TotalPoverty  Weatherstr weatherEventGroup ZoningGroup
# 0           Other         598.0         NaN               NaN      Office
# 1           Other         874.0         NaN               NaN      Office
# 2  Family_Offense          66.5        Rain              Rain
# 3         Traffic          12.0        Rain              Rain
# 4         Traffic         272.0         NaN               NaN
#
# [5 rows x 55 columns]

# %%
INC.shape
# Out:
# (93014, 55)

# %%
INC.dtypes
# Out:
# Unnamed: 0                int64
# FID                       int64
# Join_Count                int64
# TARGET_FID                int64
# Join_Cou_1                int64
# TARGET_F_1                int64
# incident_i                int64
# case_numbe                int64
# incident_d               object
# incident_t               object
# incident_1               object
# address                  object
# city                     object
# state                    object
# zip                       int64
# latitude                float64
# longitude               float64
# hour_of_da                int64
# day_of_wee               object
# parent_inc               object
# date_incid               object
# SOURCE_ID                 int64
# Gi_Bin                    int64
# B25057e1                float64
# B25058e1                float64
# B25059e1                float64
# B25076e1                float64
# B25077e1                float64
# B25078e1                float64
# B25018e1                float64
# B25001e1                float64
# B25002e1                float64
# B25002e2                float64
# B25002e3                float64
# B19013e1                float64
# C17002e1                float64
# C17002e2                float64
# C17002e3                float64
# OBJECTID_1                int64
# Zoning_Cla               object
# ZoningLabe               object
# dateShort                object
# EST                      object
# MAX_TEMPERATUREF        float64
# MEAN_TEMPERATUREF       float64
# PRECIPITATIONIN          object
# EVENTS                   object
# MEAN_VISIBILITYMILES    float64
# CityName                 object
# ZipCode2                  int64
# IncidentGroup2           object
# TotalPoverty            float64
# Weatherstr               object
# weatherEventGroup        object
# ZoningGroup              object
# dtype: object

# %% [markdown]
# ### Select Columns for Model

# %%
ColstoKeep = ['incident_d', 'Join_Count', 'ZipCode2', 'latitude', 'longitude', 'hour_of_da', 'day_of_wee', 'date_incid', 
              'B25057e1', 'B25058e1', 'B25059e1', 'B25076e1', 'B25077e1', 'B25078e1', 'B25018e1', 'B25001e1', 'B25002e1', 'B25002e2', 'B25002e3', 'B19013e1',
              'EST', 'MAX_TEMPERATUREF', 'PRECIPITATIONIN', 'MEAN_VISIBILITYMILES', 
              'CityName', 'IncidentGroup2', 'TotalPoverty', 'weatherEventGroup', 'ZoningGroup']
data = INC[ColstoKeep]
data.head()
# Out:
#                incident_d  Join_Count  ZipCode2   latitude  longitude  \
# 0  12/30/2016 01:49:00 PM           1     30346  33.927104 -84.331795
# 1  01/01/2017 01:00:00 AM           1     30346  33.930271 -84.332347
# 2  12/31/2016 02:12:00 AM           1     30338  33.925571 -84.315793
# 3  12/31/2016 09:39:00 AM           1         0  33.943571 -84.331624
# 4  06/13/2016 06:07:00 PM           1     30346  33.926443 -84.337153
#
#    hour_of_da day_of_wee           date_incid  B25057e1  B25058e1  \
# 0          13     Friday  2016-12-30 00:00:00     938.5    1083.0
# 1           1     Sunday  2017-01-01 00:00:00     911.0    1041.0
# 2           2   Saturday  2016-12-31 00:00:00     472.0     527.0
# 3           9   Saturday  2016-12-31 00:00:00     951.0    1046.5
# 4          18     Monday  2016-06-13 00:00:00     922.5    1108.0
#
#       ...       B19013e1         EST  MAX_TEMPERATUREF  PRECIPITATIONIN  \
# 0     ...        55712.5  2016-12-30              50.0             0.00
# 1     ...        67422.0         NaN               NaN              NaN
# 2     ...        85000.5  2016-12-31              47.0             0.17
# 3     ...       111182.0  2016-12-31              47.0             0.17
# 4     ...        67008.5   2016-6-13              99.0             0.00
#
#    MEAN_VISIBILITYMILES  CityName  IncidentGroup2  TotalPoverty  \
# 0                  10.0  DUNWOODY           Other         598.0
# 1                   NaN  DUNWOODY           Other         874.0
# 2                   9.0  DUNWOODY  Family_Offense          66.5
# 3                   9.0  DUNWOODY         Traffic          12.0
# 4                  10.0  DUNWOODY         Traffic         272.0
#
#    weatherEventGroup  ZoningGroup
# 0                NaN       Office
# 1                NaN       Office
# 2               Rain
# 3               Rain
# 4                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Number of Incidents

# %%
data['Join_Count'].value_counts()
# Join Count is column from Index Grid Join
# Out:
# 1    93012
# 2        2
# Name: Join_Count, dtype: int64

# %%
INC['IncidentGroup2'].value_counts()
# Count of Crimes by type
# Out:
# Theft                   25150
# Traffic                 17968
# Other                   13026
# Property_Crime          11218
# Breaking_Enter           5537
# Disorder                 5316
# Assault                  5201
# Traffic_DUI              2826
# Family_Offense           2709
# Drugs                    1481
# Robbery                   831
# Missing Person            686
# Vehicle Recovery          278
# Quality of Life           277
# Death                     159
# Weapons Offense           154
# Other Sexual Offense       72
# Liquor                     53
# Arson                      37
# Homicide                   18
# Sexual Offense             16
# Proactive Policing          1
# Name: IncidentGroup2, dtype: int64

# %% [markdown]
# https://www.youtube.com/watch?v=YPItfQ87qjM

# %% [markdown]
# **dataM** Data Frame with Top 10 Incidents

# %%
# old way
# Categories[
#            (Categories.IncidentGroup2 == "Theft") | 
#            (Categories.IncidentGroup2 == "Traffic") |
#            (Categories.IncidentGroup2 == "Property Crime") |
#            (Categories.IncidentGroup2 == "Breaking & Entering") |
#            (Categories.IncidentGroup2 == "Disorder") | 
#            (Categories.IncidentGroup2 == "Assault") |
#            (Categories.IncidentGroup2 == "Traffic - DUI") |
#            (Categories.IncidentGroup2 == "Family Offense") |
#            (Categories.IncidentGroup2 == "Drugs")
# ].head(20)

# better way
valuesToKeep = ["Theft","Traffic","Property_Crime","Breaking_Enter","Disorder","Assault",
               "Traffic_DUI", "Family_Offense","Drugs", "Robbery"]

dataM = data[ data.IncidentGroup2.isin(valuesToKeep) ]
dataM.IncidentGroup2.unique()

# Keeping top 10 Crimes for model
# Out:
# array(['Family_Offense', 'Traffic', 'Disorder', 'Theft', 'Assault',
#        'Property_Crime', 'Breaking_Enter', 'Drugs', 'Traffic_DUI',
#        'Robbery'], dtype=object)

# %% [markdown]
# Total of 93,014 Incidents in Sandy Springs and Dunwoody from 2010 to 2016 <br/>
# Select out Top 10 Crimes - left with 78,237 records

# %%
print data.shape
print dataM.shape
# Out:
# (93014, 29)
# (78237, 29)

# %% [markdown]
# Should have spatial joined the Incident points to a Zip Code layer - I don't expect Zip Code to be significant <br/>
# Zip Codes that has less than 100 Incident events were classified as 0.

# %%
dataM['ZipCode2'].value_counts()
# Out:
# 0        53665
# 30338     9084
# 30346     8772
# 30360     2171
# 30328     1979
# 30350     1646
# 30342      769
# 30327      151
# Name: ZipCode2, dtype: int64

# %%
print data.weatherEventGroup.value_counts()
print dataM.weatherEventGroup.value_counts()
# Out:
# Rain    28900
# Fog      5514
# Snow      532
# Name: weatherEventGroup, dtype: int64
# Rain    24268
# Fog      4670
# Snow      448
# Name: weatherEventGroup, dtype: int64

# %%
print "ORIGINAL {} no weather Event".format(93014 - (28900 + 5514 + 532))
print "new df {} no weather Event".format(78237 - (24268 + 4670 + 448))
# Out:
# ORIGINAL 58068 no weather Event
# new df 48851 no weather Event

# %% [markdown]
# 62% of Incidents occured with on a day with no "weather event"
# * Weather Event
#     * Rain
#     * Fog
#     * Snow

# %%
print "ORGINAL {}% incidents no weather event".format((58068.0/93014)*100)
print "new df {}% incidents no weather event".format((48851.0/78237)*100)
# Out:
# ORGINAL 62.4293117165% incidents no weather event
# new df 62.439766351% incidents no weather event

# %%
dataM.ZoningGroup.value_counts()
# Out:
#                   26700
# Commercial        16841
# Multi_Dwelling    11899
# Office             6989
# Multi_Family       6421
# Single_Family      4936
# MIX                2295
# CUP                 923
# Townhouse           793
# Industrial          203
# Agriculture         177
# NUP                  60
# Name: ZoningGroup, dtype: int64

# %% [markdown]
# Incident points that were recorded where the X, Y fell in the road - were not spatially joined to Zoning. <br/>
# Can be due to the officer writing a report from the car = no Zoning Recorded
# Incident event could occur in the Road but then the report could be recorded while pulled over into a parking lot = Zoning recorded <br/><br/>
# 34% of Indidents have no Zoning Group

# %%
print "ORIGINAL {}% incidents point landed in the road (no Zoning)".format((31866.0/93014)*100)
print "new df {}% incidents point landed in the road (no Zoning)".format((26561.0/77406)*100)
# Out:
# ORIGINAL 34.2593588062% incidents point landed in the road (no Zoning)
# new df 34.3138774772% incidents point landed in the road (no Zoning)

# %%
dataM.head()
# Out:
#                incident_d  Join_Count  ZipCode2   latitude  longitude  \
# 2  12/31/2016 02:12:00 AM           1     30338  33.925571 -84.315793
# 3  12/31/2016 09:39:00 AM           1         0  33.943571 -84.331624
# 4  06/13/2016 06:07:00 PM           1     30346  33.926443 -84.337153
# 5  06/13/2016 06:40:00 PM           1         0  33.943571 -84.331624
# 7  04/25/2016 01:58:00 PM           1     30346  33.925912 -84.336548
#
#    hour_of_da day_of_wee           date_incid  B25057e1  B25058e1  \
# 2           2   Saturday  2016-12-31 00:00:00     472.0     527.0
# 3           9   Saturday  2016-12-31 00:00:00     951.0    1046.5
# 4          18     Monday  2016-06-13 00:00:00     922.5    1108.0
# 5          18     Monday  2016-06-13 00:00:00     951.0    1046.5
# 7          13     Monday  2016-04-25 00:00:00     922.5    1108.0
#
#       ...       B19013e1         EST  MAX_TEMPERATUREF  PRECIPITATIONIN  \
# 2     ...        85000.5  2016-12-31              47.0             0.17
# 3     ...       111182.0  2016-12-31              47.0             0.17
# 4     ...        67008.5   2016-6-13              99.0             0.00
# 5     ...       111182.0   2016-6-13              99.0             0.00
# 7     ...        67008.5   2016-4-25              81.0             0.00
#
#    MEAN_VISIBILITYMILES  CityName  IncidentGroup2  TotalPoverty  \
# 2                   9.0  DUNWOODY  Family_Offense          66.5
# 3                   9.0  DUNWOODY         Traffic          12.0
# 4                  10.0  DUNWOODY         Traffic         272.0
# 5                  10.0  DUNWOODY         Traffic          12.0
# 7                  10.0  DUNWOODY        Disorder         272.0
#
#    weatherEventGroup  ZoningGroup
# 2               Rain
# 3               Rain
# 4                NaN
# 5                NaN
# 7                NaN       Office
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Set Date to Index
# ### yyyy-mm-dd hh:mm:sec

# %%
# set "indcident_d" to index and set index as datetime.
dataM['Date'] = pd.to_datetime(dataM['incident_d'])
dataM.set_index('Date', inplace=True)

# create year column from date index
dataM['Year'] = dataM.index.year
# create month column from date index
dataM['Month'] = dataM.index.month
# create day column from date index
dataM['Day'] = dataM.index.dayofweek
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dataM.head()
# check Year, Month, Day column is there
# Out:
#                                  incident_d  Join_Count  ZipCode2   latitude  \
# Date
# 2016-12-31 02:12:00  12/31/2016 02:12:00 AM           1     30338  33.925571
# 2016-12-31 09:39:00  12/31/2016 09:39:00 AM           1         0  33.943571
# 2016-06-13 18:07:00  06/13/2016 06:07:00 PM           1     30346  33.926443
# 2016-06-13 18:40:00  06/13/2016 06:40:00 PM           1         0  33.943571
# 2016-04-25 13:58:00  04/25/2016 01:58:00 PM           1     30346  33.925912
#
#                      longitude  hour_of_da day_of_wee           date_incid  \
# Date
# 2016-12-31 02:12:00 -84.315793           2   Saturday  2016-12-31 00:00:00
# 2016-12-31 09:39:00 -84.331624           9   Saturday  2016-12-31 00:00:00
# 2016-06-13 18:07:00 -84.337153          18     Monday  2016-06-13 00:00:00
# 2016-06-13 18:40:00 -84.331624          18     Monday  2016-06-13 00:00:00
# 2016-04-25 13:58:00 -84.336548          13     Monday  2016-04-25 00:00:00
#
#                      B25057e1  B25058e1 ...   PRECIPITATIONIN  \
# Date                                    ...
# 2016-12-31 02:12:00     472.0     527.0 ...              0.17
# 2016-12-31 09:39:00     951.0    1046.5 ...              0.17
# 2016-06-13 18:07:00     922.5    1108.0 ...              0.00
# 2016-06-13 18:40:00     951.0    1046.5 ...              0.00
# 2016-04-25 13:58:00     922.5    1108.0 ...              0.00
#
#                      MEAN_VISIBILITYMILES  CityName  IncidentGroup2  \
# Date
# 2016-12-31 02:12:00                   9.0  DUNWOODY  Family_Offense
# 2016-12-31 09:39:00                   9.0  DUNWOODY         Traffic
# 2016-06-13 18:07:00                  10.0  DUNWOODY         Traffic
# 2016-06-13 18:40:00                  10.0  DUNWOODY         Traffic
# 2016-04-25 13:58:00                  10.0  DUNWOODY        Disorder
#
#                      TotalPoverty  weatherEventGroup  ZoningGroup  Year  \
# Date
# 2016-12-31 02:12:00          66.5               Rain               2016
# 2016-12-31 09:39:00          12.0               Rain               2016
# 2016-06-13 18:07:00         272.0                NaN               2016
# 2016-06-13 18:40:00          12.0                NaN               2016
# 2016-04-25 13:58:00         272.0                NaN       Office  2016
#
#                      Month  Day
# Date
# 2016-12-31 02:12:00     12    5
# 2016-12-31 09:39:00     12    5
# 2016-06-13 18:07:00      6    0
# 2016-06-13 18:40:00      6    0
# 2016-04-25 13:58:00      4    0
#
# [5 rows x 32 columns]

# %%
dataM.to_csv('Data/dataM.csv')
# export dataM as dataM.csv for time series Viz

# %%
dfM = pd.read_csv('Data/dataM.csv')
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfM.head(1)
# Index no longer date whyyyyyy?
# Out:
#                   Date              incident_d  Join_Count  ZipCode2  \
# 0  2016-12-31 02:12:00  12/31/2016 02:12:00 AM           1     30338
#
#     latitude  longitude  hour_of_da day_of_wee           date_incid  B25057e1  \
# 0  33.925571 -84.315793           2   Saturday  2016-12-31 00:00:00     472.0
#
#   ...   PRECIPITATIONIN  MEAN_VISIBILITYMILES  CityName  IncidentGroup2  \
# 0 ...              0.17                   9.0  DUNWOODY  Family_Offense
#
#    TotalPoverty  weatherEventGroup  ZoningGroup  Year  Month  Day
# 0          66.5               Rain               2016     12    5
#
# [1 rows x 33 columns]

# %% [markdown]
# Now going to build Random Forest Classification Model on the Data Frame.  Reminder - these rows are Incident point from Sandy Springs and Dunwoody

# %% [markdown]
# ### dataM

# %%
dataM.drop('incident_d', axis = 1, inplace = True)
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dataM.dtypes
# ready to model
# ...maybe, hopefully ... 
# X is everything except "IncidentGroup2"
# Y is "IncidentGroup2" 10 categories
# Out:
# Join_Count                int64
# ZipCode2                  int64
# latitude                float64
# longitude               float64
# hour_of_da                int64
# day_of_wee               object
# date_incid               object
# B25057e1                float64
# B25058e1                float64
# B25059e1                float64
# B25076e1                float64
# B25077e1                float64
# B25078e1                float64
# B25018e1                float64
# B25001e1                float64
# B25002e1                float64
# B25002e2                float64
# B25002e3                float64
# B19013e1                float64
# EST                      object
# MAX_TEMPERATUREF        float64
# PRECIPITATIONIN          object
# MEAN_VISIBILITYMILES    float64
# CityName                 object
# IncidentGroup2           object
# TotalPoverty            float64
# weatherEventGroup        object
# ZoningGroup              object
# Year                      int32
# Month                     int32
# Day                       int32
# dtype: object

# %% [markdown]
# ## dfMCats
# Data Frame for Model with Dummy Variables on the Categoricial Columns including Incident Group - which are the 10 targets for the model

# %%
dfMCats = dataM

# %% [markdown]
# ## Encoding Categories
# Random Forest needs all the columns to contain numerical values <br/>
# All the Categories will be cast to an Integer. Each integer (aka number) corresponds to each category in a given Categorical Column <br/>
# Categorical Columns still in for Model and Dummy Variables created from the Categories <br/>
# The Encoded Column will serve to see if that has feature importance - the Dummy Variables from that Column identifies which values of that column was most important

# %%
#  ********
# lets say one column for gender has 3 values, "M", "F", "U"
# call that column gender

# genderKeys = df.gender.unique().tolist()
# genderWithInts = zip(genderKeys, range(len(genderKeys)))
# genderToIntDict = dict( genderWithInts )

# # genderToIntDict will return {"M" : 1, "F" : 2, "U" : 3}

# def genderToInt(gender):
# 	return genderToIntDict[gender]

# df["gender"] = df.gender.apply(genderToInt)
#  ******

# %% [markdown]
# Categorical Columns to Encode
#  * Day of the Week
#  * City Name
#  * Weather Event
#  * Zoning Type
#  * Incident Group
#  * Precipitation - make sure is int

# %%
dfMCats.columns
# Out:
# Index([u'Join_Count', u'ZipCode2', u'latitude', u'longitude', u'hour_of_da',
#        u'day_of_wee', u'date_incid', u'B25057e1', u'B25058e1', u'B25059e1',
#        u'B25076e1', u'B25077e1', u'B25078e1', u'B25018e1', u'B25001e1',
#        u'B25002e1', u'B25002e2', u'B25002e3', u'B19013e1', u'EST',
#        u'MAX_TEMPERATUREF', u'PRECIPITATIONIN', u'MEAN_VISIBILITYMILES',
#        u'CityName', u'IncidentGroup2', u'TotalPoverty', u'weatherEventGroup',
#        u'ZoningGroup', u'Year', u'Month', u'Day'],
#       dtype='object')

# %% [markdown]
# ### Day of the Week

# %%
dayofWeek = dfMCats.day_of_wee.unique().tolist()
dayofWeek
# Out:
# ['Saturday', 'Monday', 'Thursday', 'Friday', 'Tuesday', 'Sunday', 'Wednesday']

# %%
IndexNumforWeek = [7, 2, 5, 6, 3, 1, 4]
# Sun = 1
# Mon = 2
# Tue = 3
# Wed = 4
# Ths = 5 
# Fri = 6
# Sat = 7

# %%
WeekNum = zip(dayofWeek, IndexNumforWeek)
WeekNum
# Out:
# [('Saturday', 7),
#  ('Monday', 2),
#  ('Thursday', 5),
#  ('Friday', 6),
#  ('Tuesday', 3),
#  ('Sunday', 1),
#  ('Wednesday', 4)]

# %%
WeekNumDict = dict(WeekNum)
WeekNumDict
# brackets to curly brackets
# Out:
# {'Friday': 6,
#  'Monday': 2,
#  'Saturday': 7,
#  'Sunday': 1,
#  'Thursday': 5,
#  'Tuesday': 3,
#  'Wednesday': 4}

# %%
def WeekToInt(week):
    return WeekNumDict[week]

dfMCats['WeekNum'] = dfMCats.day_of_wee.apply(WeekToInt)
dfMCats.WeekNum.unique()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([7, 2, 5, 6, 3, 1, 4], dtype=int64)

# %% [markdown]
# ### City Name

# %%
dfMCats.CityName.value_counts()
# Out:
# SANDY SPRINGS    52195
# DUNWOODY         25799
# DORAVILLE          125
# ATLANTA            115
# GCO                  2
# CHAMBLEE             1
# Name: CityName, dtype: int64

# %%
City = sorted(dfMCats.CityName.unique().tolist())
City
# Out:
# ['ATLANTA', 'CHAMBLEE', 'DORAVILLE', 'DUNWOODY', 'GCO', 'SANDY SPRINGS']

# %%
CityNum = zip(City, range(len(City)))
# CityNum
Citydict = dict(CityNum)
Citydict
# Out:
# {'ATLANTA': 0,
#  'CHAMBLEE': 1,
#  'DORAVILLE': 2,
#  'DUNWOODY': 3,
#  'GCO': 4,
#  'SANDY SPRINGS': 5}

# %%
def CitytoInt(City):
    return Citydict[City]

dfMCats["CityNum"] = dfMCats.CityName.apply(CitytoInt)
dfMCats.CityNum.unique()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([3, 5, 0, 2, 4, 1], dtype=int64)

# %% [markdown]
# ### Weather Event to Numbers

# %%
weatherEvent = sorted(dfMCats.weatherEventGroup.unique().tolist())
WeatherNum = dict(zip(weatherEvent, range(len(weatherEvent))))
WeatherNum
# Out:
# {nan: 0, 'Fog': 1, 'Rain': 2, 'Snow': 3}

# %%
def weathertoInt(weatherEvent):
    return WeatherNum[weatherEvent]

dfMCats['WeatherEventNum'] = dfMCats.weatherEventGroup.apply(weathertoInt)
dfMCats.WeatherEventNum.unique()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([2, 0, 1, 3], dtype=int64)

# %% [markdown]
# ### Zoning Group

# %%
ZoneGroup = sorted(dfMCats.ZoningGroup.unique().tolist())
ZoneGroup
# Out:
# [' ',
#  'Agriculture',
#  'CUP',
#  'Commercial',
#  'Industrial',
#  'MIX',
#  'Multi_Dwelling',
#  'Multi_Family',
#  'NUP',
#  'Office',
#  'Single_Family',
#  'Townhouse']

# %%
ZoneNum = dict(zip(ZoneGroup, range(len(ZoneGroup))))
ZoneNum
# Out:
# {' ': 0,
#  'Agriculture': 1,
#  'CUP': 2,
#  'Commercial': 3,
#  'Industrial': 4,
#  'MIX': 5,
#  'Multi_Dwelling': 6,
#  'Multi_Family': 7,
#  'NUP': 8,
#  'Office': 9,
#  'Single_Family': 10,
#  'Townhouse': 11}

# %%
def ZonetoInt(Zone):
    return ZoneNum[Zone]

dfMCats['ZoneNum'] = dfMCats.ZoningGroup.apply(ZonetoInt)
dfMCats.ZoneNum.unique()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([ 0,  9,  3,  7, 10,  6,  1, 11,  5,  2,  4,  8], dtype=int64)

# %% [markdown]
# ### Incident Group

# %%
IncGroup = sorted(dfMCats.IncidentGroup2.unique().tolist())
IncNum = dict(zip(IncGroup, range(len(IncGroup))))
IncNum
# Out:
# {'Assault': 0,
#  'Breaking_Enter': 1,
#  'Disorder': 2,
#  'Drugs': 3,
#  'Family_Offense': 4,
#  'Property_Crime': 5,
#  'Robbery': 6,
#  'Theft': 7,
#  'Traffic': 8,
#  'Traffic_DUI': 9}

# %%
def InctoInt(Incident):
    return IncNum[Incident]

dfMCats['IncNum'] = dfMCats.IncidentGroup2.apply(InctoInt)
dfMCats.IncNum.unique()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([4, 8, 2, 7, 0, 5, 1, 3, 9, 6], dtype=int64)

# %% [markdown]
# ### Make Precipitation Column be Numbers
# http://help.wunderground.com/knowledgebase/articles/656875-what-does-t-stand-for-on-the-rain-precipitation <br/>
# Column came with float types and this frisky "T"
# ```
# T stands for "trace", used when precipitation has been detected, but it isn't sufficient to measure meaningfully
# ```

# %%
def castFloat(value):
    try:
        return float(value)
    except ValueError:
        return 0
    
dfMCats['PRECIPITATIONIN'] = dfMCats.PRECIPITATIONIN.apply(castFloat)
dfMCats.PRECIPITATIONIN.max()
# Out:
# C:\Users\Amber\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 4.1100000000000003

# %% [markdown]
# #### Alternatively Can also Enumerate all of the Columns in the DataFrame

# %% [markdown]
# http://stackoverflow.com/questions/24458645/label-encoding-across-multiple-columns-in-scikit-learn

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
d = defaultdict(LabelEncoder)

# %%
# dfMCats.drop(CategoriesforEncode, axis = 1, inplace = True)
# dataM.drop('incident_d', axis = 1, inplace = True)

# %%
# stuff that almost works 
# CategoriesforEncode = ["day_of_wee", "CityName", "weatherEventGroup", "ZoningGroup", "IncidentGroup2"]
# dfMCatsEnc = dfMCats.join(dfMCats[CategoriesforEncode].apply(LabelEncoder().fit_transform), 
#                           how='left', rsuffix='Enc')
# dfMCatsEnc.head()

# %%
from collections import defaultdict
d = defaultdict(LabelEncoder)

# %%
Enc = dfMCats.apply(lambda x: d[x.name].fit_transform(x))
# enumerates everything in the Data Frame with fit_transform()
Enc.head()
# Out:
#             Join_Count  ZipCode2  latitude  longitude  hour_of_da  day_of_wee  \
# Date
# 2010-01-01           0         0     13793      16550           0           0
# 2010-01-01           0         0     13793      16550           0           0
# 2010-01-01           0         0     13793      16550           0           0
# 2010-01-01           0         0      4805       8547           0           0
# 2010-01-01           0         0      4805       8547           0           0
#
#             date_incid  B25057e1  B25058e1  B25059e1  \
# Date
# 2010-01-01           0       128        99       153
# 2010-01-01           0       128        99       153
# 2010-01-01           0       128        99       153
# 2010-01-01           0       236       291       271
# 2010-01-01           0       236       291       271
#
#                        ...              IncidentGroup2_Assault  \
# Date                   ...
# 2010-01-01             ...                                   0
# 2010-01-01             ...                                   0
# 2010-01-01             ...                                   0
# 2010-01-01             ...                                   0
# 2010-01-01             ...                                   0
#
#             IncidentGroup2_Breaking_Enter  IncidentGroup2_Disorder  \
# Date
# 2010-01-01                              0                        0
# 2010-01-01                              0                        0
# 2010-01-01                              0                        1
# 2010-01-01                              0                        0
# 2010-01-01                              0                        0
#
#             IncidentGroup2_Drugs  IncidentGroup2_Family_Offense  \
# Date
# 2010-01-01                     0                              0
# 2010-01-01                     0                              0
# 2010-01-01                     0                              0
# 2010-01-01                     0                              0
# 2010-01-01                     0                              0
#
#             IncidentGroup2_Property_Crime  IncidentGroup2_Robbery  \
# Date
# 2010-01-01                              1                       0
# 2010-01-01                              0                       0
# 2010-01-01                              0                       0
# 2010-01-01                              1                       0
# 2010-01-01                              0                       0
#
#             IncidentGroup2_Theft  IncidentGroup2_Traffic  \
# Date
# 2010-01-01                     0                       0
# 2010-01-01                     1                       0
# 2010-01-01                     0                       0
# 2010-01-01                     0                       0
# 2010-01-01                     1                       0
#
#             IncidentGroup2_Traffic_DUI
# Date
# 2010-01-01                           0
# 2010-01-01                           0
# 2010-01-01                           0
# 2010-01-01                           0
# 2010-01-01                           0
#
# [5 rows x 69 columns]

# %%
Reverse = Enc.apply(lambda x: d[x.name].inverse_transform(x))
# And brings the original values back with inverse_transform()
Reverse.head()
# this is still cool
# Out:
#             Join_Count  ZipCode2   latitude  longitude  hour_of_da day_of_wee  \
# Date
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.919469 -84.359070           0     Friday
# 2010-01-01           1         0  33.919469 -84.359070           0     Friday
#
#                      date_incid  B25057e1  B25058e1  B25059e1  \
# Date
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     834.0    1115.5    1315.5
# 2010-01-01  2010-01-01 00:00:00     834.0    1115.5    1315.5
#
#                       ...              IncidentGroup2_Assault  \
# Date                  ...
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
#
#             IncidentGroup2_Breaking_Enter  IncidentGroup2_Disorder  \
# Date
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      1.0
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      0.0
#
#             IncidentGroup2_Drugs  IncidentGroup2_Family_Offense  \
# Date
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
#
#             IncidentGroup2_Property_Crime  IncidentGroup2_Robbery  \
# Date
# 2010-01-01                            1.0                     0.0
# 2010-01-01                            0.0                     0.0
# 2010-01-01                            0.0                     0.0
# 2010-01-01                            1.0                     0.0
# 2010-01-01                            0.0                     0.0
#
#             IncidentGroup2_Theft  IncidentGroup2_Traffic  \
# Date
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   1.0                     0.0
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   1.0                     0.0
#
#            IncidentGroup2_Traffic_DUI
# Date
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
#
# [5 rows x 69 columns]

# %%
print dfMCats.shape
print dfMCatEnc.shape
print Enc.shape
# Out:
# (78237, 36)
# (85761, 69)
# (85761, 69)

# %% [markdown]
# ### Make Dummy Variables on the Categorical Columns

# %%
# Making Dummies after Encoding so that the Incident Group dummy variables go at the end of the Data Frame
CategoriesforDummies = ["day_of_wee", "CityName", "weatherEventGroup", "ZoningGroup", "IncidentGroup2"]
Categories = dfMCats[CategoriesforDummies]
print Categories.head()
dummies = pd.get_dummies(Categories)
# dummies.head()
dfMCats = dfMCats.join(dummies)
dfMCats.head()
# Out:
#                     day_of_wee  CityName weatherEventGroup ZoningGroup  \
# Date
# 2016-12-31 02:12:00   Saturday  DUNWOODY              Rain
# 2016-12-31 09:39:00   Saturday  DUNWOODY              Rain
# 2016-06-13 18:07:00     Monday  DUNWOODY               NaN
# 2016-06-13 18:40:00     Monday  DUNWOODY               NaN
# 2016-04-25 13:58:00     Monday  DUNWOODY               NaN      Office
#
#                      IncidentGroup2
# Date
# 2016-12-31 02:12:00  Family_Offense
# 2016-12-31 09:39:00         Traffic
# 2016-06-13 18:07:00         Traffic
# 2016-06-13 18:40:00         Traffic
# 2016-04-25 13:58:00        Disorder
#             Join_Count  ZipCode2   latitude  longitude  hour_of_da day_of_wee  \
# Date
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.965092 -84.314529           0     Friday
# 2010-01-01           1         0  33.919469 -84.359070           0     Friday
# 2010-01-01           1         0  33.919469 -84.359070           0     Friday
#
#                      date_incid  B25057e1  B25058e1  B25059e1  \
# Date
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     683.0     741.5    1000.5
# 2010-01-01  2010-01-01 00:00:00     834.0    1115.5    1315.5
# 2010-01-01  2010-01-01 00:00:00     834.0    1115.5    1315.5
#
#                       ...              IncidentGroup2_Assault  \
# Date                  ...
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
# 2010-01-01            ...                                 0.0
#
#             IncidentGroup2_Breaking_Enter  IncidentGroup2_Disorder  \
# Date
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      1.0
# 2010-01-01                            0.0                      0.0
# 2010-01-01                            0.0                      0.0
#
#             IncidentGroup2_Drugs  IncidentGroup2_Family_Offense  \
# Date
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
# 2010-01-01                   0.0                            0.0
#
#             IncidentGroup2_Property_Crime  IncidentGroup2_Robbery  \
# Date
# 2010-01-01                            1.0                     0.0
# 2010-01-01                            0.0                     0.0
# 2010-01-01                            0.0                     0.0
# 2010-01-01                            1.0                     0.0
# 2010-01-01                            0.0                     0.0
#
#             IncidentGroup2_Theft  IncidentGroup2_Traffic  \
# Date
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   1.0                     0.0
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   0.0                     0.0
# 2010-01-01                   1.0                     0.0
#
#            IncidentGroup2_Traffic_DUI
# Date
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
# 2010-01-01                        0.0
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Drop a few things
# Drop Categorical Columns

# %%
print dataM.shape
print dfMCats.shape
# Out:
# (78237, 36)
# (85761, 74)

# %%
CatColstoDrop = ["day_of_wee", "CityName", "weatherEventGroup", "ZoningGroup", "EST", "date_incid", "IncidentGroup2"]
# drop these columns that have text categories for the model
dfMCats.drop(CatColstoDrop, axis = 1, inplace = True)

# %%
dfMCats.columns
# Out:
# Index([u'Join_Count', u'ZipCode2', u'latitude', u'longitude', u'hour_of_da',
#        u'B25057e1', u'B25058e1', u'B25059e1', u'B25076e1', u'B25077e1',
#        u'B25078e1', u'B25018e1', u'B25001e1', u'B25002e1', u'B25002e2',
#        u'B25002e3', u'B19013e1', u'MAX_TEMPERATUREF', u'PRECIPITATIONIN',
#        u'MEAN_VISIBILITYMILES', u'TotalPoverty', u'Year', u'Month', u'Day',
#        u'WeekNum', u'CityNum', u'WeatherEventNum', u'ZoneNum', u'IncNum',
#        u'day_of_wee_Friday', u'day_of_wee_Monday', u'day_of_wee_Saturday',
#        u'day_of_wee_Sunday', u'day_of_wee_Thursday', u'day_of_wee_Tuesday',
#        u'day_of_wee_Wednesday', u'CityName_ATLANTA', u'CityName_CHAMBLEE',
#        u'CityName_DORAVILLE', u'CityName_DUNWOODY', u'CityName_GCO',
#        u'CityName_SANDY SPRINGS', u'weatherEventGroup_Fog',
#        u'weatherEventGroup_Rain', u'weatherEventGroup_Snow', u'ZoningGroup_ ',
#        u'ZoningGroup_Agriculture', u'ZoningGroup_CUP',
#        u'ZoningGroup_Commercial', u'ZoningGroup_Industrial',
#        u'ZoningGroup_MIX', u'ZoningGroup_Multi_Dwelling',
#        u'ZoningGroup_Multi_Family', u'ZoningGroup_NUP', u'ZoningGroup_Office',
#        u'ZoningGroup_Single_Family', u'ZoningGroup_Townhouse',
#        u'IncidentGroup2_Assault', u'IncidentGroup2_Breaking_Enter',
#        u'IncidentGroup2_Disorder', u'IncidentGroup2_Drugs',
#        u'IncidentGroup2_Family_Offense', u'IncidentGroup2_Property_Crime',
#        u'IncidentGroup2_Robbery', u'IncidentGroup2_Theft',
#        u'IncidentGroup2_Traffic', u'IncidentGroup2_Traffic_DUI'],
#       dtype='object')

# %% [markdown]
# ### Get rid on NaN
# - Random Forest Don't Like

# %%
dfMCats.fillna(0, inplace = True)

# %% [markdown]
# ### Correlations

# %%
dfMCats.corr()
# Out:
#                                Join_Count  ZipCode2  latitude  longitude  \
# Join_Count                       1.000000 -0.002430 -0.004987  -0.003807
# ZipCode2                        -0.002430  1.000000 -0.084056   0.472106
# CityName_GCO                     0.004639  0.002080  0.001709  0.002549
# CityName_SANDY SPRINGS          -0.036532 -0.176514 -0.146380 -0.097072
# weatherEventGroup_Fog            0.005940  0.001131  0.003270  0.005753
# weatherEventGroup_Rain           0.002679  0.012028  0.012078  0.009134
# weatherEventGroup_Snow           0.010921  0.005313  0.004223  0.004075
# ZoningGroup_                    -0.033531 -0.015756 -0.005866  0.001916
# ZoningGroup_Agriculture          0.002404 -0.072094 -0.077606 -0.080587
# ZoningGroup_CUP                 -0.006227 -0.077815 -0.088981 -0.086059
# ZoningGroup_Commercial           0.064509 -0.040265  0.019334  0.064360
# ZoningGroup_Industrial          -0.008082 -0.008469 -0.018465 -0.009806
# ZoningGroup_MIX                 -0.005470  0.047856  0.095811  0.117529
# ZoningGroup_Multi_Dwelling      -0.001062 -0.021324 -0.089541 -0.148976
# ZoningGroup_Multi_Family        -0.000372  0.078838  0.040152  0.010578
# ZoningGroup_NUP                  0.001260 -0.010583 -0.009763 -0.008765
# ZoningGroup_Office              -0.032195  0.192922  0.194877  0.173455
# ZoningGroup_Single_Family        0.005821 -0.183949 -0.189022 -0.151424
# ZoningGroup_Townhouse            0.000613  0.007573  0.010146  0.011516
# IncidentGroup2_Assault          -0.007823 -0.008381 -0.026006 -0.038488
# IncidentGroup2_Breaking_Enter   -0.070205 -0.006679 -0.025569 -0.034649
# IncidentGroup2_Disorder         -0.021962 -0.007692 -0.010820 -0.014590
# IncidentGroup2_Drugs            -0.003395  0.001093 -0.006911 -0.012603
# IncidentGroup2_Family_Offense    0.008344  0.001945 -0.019809 -0.032518
# IncidentGroup2_Property_Crime    0.005127 -0.020326 -0.020996 -0.026517
# IncidentGroup2_Robbery           0.010063 -0.004667 -0.008910 -0.009737
# IncidentGroup2_Theft             0.126853  0.110509  0.126421  0.126821
# IncidentGroup2_Traffic          -0.018210 -0.078501 -0.059446 -0.035436
# IncidentGroup2_Traffic_DUI      -0.170185 -0.040227 -0.038576 -0.031058
#
#                                B25076e1  B25077e1             ...              \
# Join_Count                    -0.002389 -0.000111             ...
# ZipCode2                       0.053115 -0.010664             ...
# latitude                      -0.297620 -0.341515             ...
# longitude                     -0.151961 -0.283374             ...
# hour_of_da                     0.007949  0.005063             ...
# B25057e1                      -0.219351 -0.220379             ...
# B25058e1                      -0.235848 -0.221451             ...
# B25059e1                      -0.162602 -0.117857             ...
# B25076e1                       1.000000  0.933710             ...
# B25077e1                       0.933710  1.000000             ...
# B25078e1                       0.835870  0.916490             ...
# B25018e1                       0.597045  0.633774             ...
# B25001e1                      -0.052467 -0.117548             ...
# B25002e1                      -0.052467 -0.117548             ...
# B25002e2                      -0.027535 -0.100655             ...
# B25002e3                      -0.159831 -0.171329             ...
# B19013e1                       0.746230  0.791404             ...
# MAX_TEMPERATUREF              -0.002431 -0.005368             ...
# PRECIPITATIONIN               -0.004270 -0.003235             ...
# MEAN_VISIBILITYMILES           0.003922  0.004281             ...
# TotalPoverty                  -0.216493 -0.261070             ...
# Year                          -0.001846 -0.003885             ...
# Month                         -0.006034 -0.005912             ...
# Day                           -0.009300 -0.005084             ...
# WeekNum                        0.012978  0.016059             ...
# CityNum                       -0.099237 -0.016134             ...
# WeatherEventNum                0.002473 -0.000421             ...
# ZoneNum                       -0.025369 -0.023170             ...
# IncNum                         0.088069  0.098040             ...
# day_of_wee_Friday              0.013682  0.013481             ...
# ...                                 ...       ...             ...
# CityName_CHAMBLEE             -0.001746 -0.002337             ...
# CityName_DORAVILLE            -0.020442 -0.027207             ...
# CityName_DUNWOODY              0.106182  0.027840             ...
# CityName_GCO                  -0.000526 -0.000976             ...
# CityName_SANDY SPRINGS        -0.101177 -0.022143             ...
# weatherEventGroup_Fog         -0.003516 -0.000279             ...
# weatherEventGroup_Rain         0.002853 -0.000890             ...
# weatherEventGroup_Snow         0.002123  0.002188             ...
# ZoningGroup_                   0.081955  0.062385             ...
# ZoningGroup_Agriculture        0.045283  0.049088             ...
# ZoningGroup_CUP                0.084777  0.072069             ...
# ZoningGroup_Commercial         0.022179  0.057084             ...
# ZoningGroup_Industrial        -0.052171 -0.054278             ...
# ZoningGroup_MIX                0.035593  0.042358             ...
# ZoningGroup_Multi_Dwelling    -0.335739 -0.310877             ...
# ZoningGroup_Multi_Family      -0.014529 -0.050308             ...
# ZoningGroup_NUP                0.015758  0.018829             ...
# ZoningGroup_Office             0.034769 -0.002703             ...
# ZoningGroup_Single_Family      0.202340  0.228692             ...
# ZoningGroup_Townhouse          0.001678  0.012294             ...
# IncidentGroup2_Assault        -0.054637 -0.057030             ...
# IncidentGroup2_Breaking_Enter -0.008615 -0.016874             ...
# IncidentGroup2_Disorder       -0.049979 -0.048130             ...
# IncidentGroup2_Drugs          -0.020456 -0.023990             ...
# IncidentGroup2_Family_Offense -0.033286 -0.037403             ...
# IncidentGroup2_Property_Crime -0.017251 -0.015047             ...
# IncidentGroup2_Robbery        -0.030997 -0.028489             ...
# IncidentGroup2_Theft           0.065240  0.059273             ...
# IncidentGroup2_Traffic         0.026741  0.034975             ...
# IncidentGroup2_Traffic_DUI     0.020760  0.031593             ...
#
#                                IncidentGroup2_Assault  \
# Join_Count                                  -0.000889
# ZipCode2                                    -0.020315
# latitude                                     0.051008
# longitude                                    0.030810
# hour_of_da                                  -0.007823
# B25057e1                                    -0.008381
# B25058e1                                    -0.026006
# B25059e1                                    -0.038488
# B25076e1                                    -0.054637
# B25077e1                                    -0.057030
# B25078e1                                    -0.063576
# B25018e1                                    -0.022308
# B25001e1                                    -0.028886
# B25002e1                                    -0.028886
# B25002e2                                    -0.027304
# B25002e3                                    -0.029787
# B19013e1                                    -0.068433
# MAX_TEMPERATUREF                            -0.002948
# PRECIPITATIONIN                             -0.001273
# MEAN_VISIBILITYMILES                        -0.001259
# TotalPoverty                                 0.061779
# Year                                        -0.052983
# Month                                       -0.003201
# Day                                          0.022934
# WeekNum                                     -0.008845
# CityNum                                      0.015576
# WeatherEventNum                             -0.008244
# ZoneNum                                      0.069003
# IncNum                                      -0.526971
# day_of_wee_Friday                           -0.006305
# ...                                               ...
# CityName_CHAMBLEE                           -0.000889
# CityName_DORAVILLE                           0.009394
# CityName_DUNWOODY                           -0.014365
# CityName_GCO                                -0.001257
# CityName_SANDY SPRINGS                       0.014332
# weatherEventGroup_Fog                       -0.001184
# weatherEventGroup_Rain                      -0.006465
# weatherEventGroup_Snow                      -0.006185
# ZoningGroup_                                -0.069598
# ZoningGroup_Agriculture                      0.000624
# ZoningGroup_CUP                              0.007454
# ZoningGroup_Commercial                      -0.042060
# ZoningGroup_Industrial                      -0.008786
# ZoningGroup_MIX                             -0.007390
# ZoningGroup_Multi_Dwelling                   0.116350
# ZoningGroup_Multi_Family                     0.060036
# ZoningGroup_NUP                              0.000001
# ZoningGroup_Office                          -0.020967
# ZoningGroup_Single_Family                   -0.005742
# ZoningGroup_Townhouse                        0.009931
# IncidentGroup2_Assault                       1.000000
# IncidentGroup2_Breaking_Enter               -0.075064
# IncidentGroup2_Disorder                     -0.068146
# IncidentGroup2_Drugs                        -0.035030
# IncidentGroup2_Family_Offense               -0.047980
# IncidentGroup2_Property_Crime               -0.107082
# IncidentGroup2_Robbery                      -0.026187
# IncidentGroup2_Theft                        -0.187097
# IncidentGroup2_Traffic                      -0.136883
# IncidentGroup2_Traffic_DUI                  -0.048234
#
#                                IncidentGroup2_Breaking_Enter  \
# Join_Count                                         -0.000985
# ZipCode2                                           -0.006133
# latitude                                            0.040694
# longitude                                           0.019822
# hour_of_da                                         -0.070205
# B25057e1                                           -0.006679
# B25058e1                                           -0.025569
# B25059e1                                           -0.034649
# B25076e1                                           -0.008615
# B25077e1                                           -0.016874
# B25078e1                                           -0.029372
# B25018e1                                            0.000512
# B25001e1                                           -0.008451
# B25002e1                                           -0.008451
# B25002e2                                           -0.010005
# B25002e3                                            0.000953
# B19013e1                                           -0.030495
# MAX_TEMPERATUREF                                    0.028415
# PRECIPITATIONIN                                    -0.011197
# MEAN_VISIBILITYMILES                               -0.028517
# TotalPoverty                                        0.012414
# Year                                               -0.013842
# Month                                               0.017022
# Day                                                -0.028442
# WeekNum                                             0.010718
# CityNum                                             0.006067
# WeatherEventNum                                     0.018524
# ZoneNum                                             0.159324
# IncNum                                             -0.467849
# day_of_wee_Friday                                   0.003441
# ...                                                      ...
# CityName_CHAMBLEE                                  -0.000985
# CityName_DORAVILLE                                  0.005497
# CityName_DUNWOODY                                  -0.004331
# CityName_GCO                                       -0.001392
# CityName_SANDY SPRINGS                              0.004874
# weatherEventGroup_Fog                              -0.000764
# weatherEventGroup_Rain                              0.020573
# weatherEventGroup_Snow                             -0.007194
# ZoningGroup_                                       -0.105947
# ZoningGroup_Agriculture                             0.006469
# ZoningGroup_CUP                                     0.000977
# ZoningGroup_Commercial                             -0.094510
# ZoningGroup_Industrial                             -0.005087
# ZoningGroup_MIX                                    -0.005207
# ZoningGroup_Multi_Dwelling                          0.093886
# ZoningGroup_Multi_Family                            0.071487
# ZoningGroup_NUP                                     0.011584
# ZoningGroup_Office                                  0.040152
# ZoningGroup_Single_Family                           0.093739
# ZoningGroup_Townhouse                               0.015674
# IncidentGroup2_Assault                             -0.075064
# IncidentGroup2_Breaking_Enter                       1.000000
# IncidentGroup2_Disorder                            -0.075468
# IncidentGroup2_Drugs                               -0.038794
# IncidentGroup2_Family_Offense                      -0.053134
# IncidentGroup2_Property_Crime                      -0.118587
# IncidentGroup2_Robbery                             -0.029001
# IncidentGroup2_Theft                               -0.207198
# IncidentGroup2_Traffic                             -0.151589
# IncidentGroup2_Traffic_DUI                         -0.053416
#
#                                IncidentGroup2_Disorder  IncidentGroup2_Drugs  \
# Join_Count                                    0.013046             -0.000459
# ZipCode2                                     -0.056347              0.039123
# latitude                                      0.037260              0.013908
# longitude                                    -0.035261              0.047620
# hour_of_da                                   -0.021962             -0.003395
# B25057e1                                     -0.007692              0.001093
# B25058e1                                     -0.010820             -0.006911
# B25059e1                                     -0.014590             -0.012603
# B25076e1                                     -0.049979             -0.020456
# B25077e1                                     -0.048130             -0.023990
# B25078e1                                     -0.045008             -0.031635
# B25018e1                                     -0.018421             -0.001016
# B25001e1                                     -0.037797              0.000231
# B25002e1                                     -0.037797              0.000231
# B25002e2                                     -0.036774              0.000710
# B25002e3                                     -0.033956             -0.002121
# B19013e1                                     -0.056996             -0.015121
# MAX_TEMPERATUREF                             -0.002078             -0.000455
# PRECIPITATIONIN                              -0.006920             -0.008397
# MEAN_VISIBILITYMILES                          0.011840              0.008064
# TotalPoverty                                  0.026605              0.008543
# Year                                         -0.014098              0.008919
# Month                                         0.006331             -0.006196
# Day                                           0.004389             -0.007375
# WeekNum                                      -0.005648              0.003445
# CityNum                                       0.076001             -0.038109
# WeatherEventNum                              -0.012438             -0.007901
# ZoneNum                                       0.043227             -0.028378
# IncNum                                       -0.343716             -0.128215
# day_of_wee_Friday                            -0.001865             -0.000920
# ...                                                ...                   ...
# CityName_CHAMBLEE                            -0.000894             -0.000459
# CityName_DORAVILLE                           -0.003635              0.003201
# CityName_DUNWOODY                            -0.079021              0.039497
# CityName_GCO                                 -0.001264             -0.000650
# CityName_SANDY SPRINGS                        0.080123             -0.039252
# weatherEventGroup_Fog                         0.000184             -0.004921
# weatherEventGroup_Rain                       -0.012209             -0.007282
# weatherEventGroup_Snow                       -0.001365              0.002398
# ZoningGroup_                                 -0.056370              0.040549
# ZoningGroup_Agriculture                      -0.000503             -0.000866
# ZoningGroup_CUP                               0.015953             -0.010609
# ZoningGroup_Commercial                       -0.010293             -0.029774
# ZoningGroup_Industrial                        0.005784              0.000675
# ZoningGroup_MIX                               0.008358             -0.004332
# ZoningGroup_Multi_Dwelling                    0.078745              0.006279
# ZoningGroup_Multi_Family                      0.005592              0.002822
# ZoningGroup_NUP                               0.006958             -0.003648
# ZoningGroup_Office                           -0.007002             -0.009652
# ZoningGroup_Single_Family                    -0.005407             -0.018688
# ZoningGroup_Townhouse                         0.013966             -0.006251
# IncidentGroup2_Assault                       -0.068146             -0.035030
# IncidentGroup2_Breaking_Enter                -0.075468             -0.038794
# IncidentGroup2_Disorder                       1.000000             -0.035219
# IncidentGroup2_Drugs                         -0.035219              1.000000
# IncidentGroup2_Family_Offense                -0.048238             -0.024796
# IncidentGroup2_Property_Crime                -0.107659             -0.055341
# IncidentGroup2_Robbery                       -0.026328             -0.013534
# IncidentGroup2_Theft                         -0.188104             -0.096694
# IncidentGroup2_Traffic                       -0.137620             -0.070743
# IncidentGroup2_Traffic_DUI                   -0.048494             -0.024928
#
#                                IncidentGroup2_Family_Offense  \
# Join_Count                                         -0.000629
# ZipCode2                                            0.017211
# latitude                                            0.029623
# longitude                                           0.048858
# hour_of_da                                          0.008344
# B25057e1                                            0.001945
# B25058e1                                           -0.019809
# B25059e1                                           -0.032518
# B25076e1                                           -0.033286
# B25077e1                                           -0.037403
# B25078e1                                           -0.047862
# B25018e1                                           -0.006955
# B25001e1                                           -0.023609
# B25002e1                                           -0.023609
# B25002e2                                           -0.022195
# B25002e3                                           -0.024924
# B19013e1                                           -0.056258
# MAX_TEMPERATUREF                                   -0.004929
# PRECIPITATIONIN                                     0.002242
# MEAN_VISIBILITYMILES                                0.002636
# TotalPoverty                                        0.060183
# Year                                                0.020325
# Month                                               0.001301
# Day                                                 0.020731
# WeekNum                                            -0.013101
# CityNum                                            -0.008712
# WeatherEventNum                                    -0.000311
# ZoneNum                                             0.071511
# IncNum                                             -0.106991
# day_of_wee_Friday                                  -0.005885
# ...                                                      ...
# CityName_CHAMBLEE                                  -0.000629
# CityName_DORAVILLE                                  0.006976
# CityName_DUNWOODY                                   0.009840
# CityName_GCO                                       -0.000890
# CityName_SANDY SPRINGS                             -0.010570
# weatherEventGroup_Fog                               0.000961
# weatherEventGroup_Rain                             -0.001085
# weatherEventGroup_Snow                              0.002153
# ZoningGroup_                                       -0.049294
# ZoningGroup_Agriculture                            -0.003304
# ZoningGroup_CUP                                     0.006541
# ZoningGroup_Commercial                             -0.073658
# ZoningGroup_Industrial                             -0.004970
# ZoningGroup_MIX                                    -0.007688
# ZoningGroup_Multi_Dwelling                          0.100253
# ZoningGroup_Multi_Family                            0.069834
# ZoningGroup_NUP                                    -0.002582
# ZoningGroup_Office                                 -0.017069
# ZoningGroup_Single_Family                           0.017041
# ZoningGroup_Townhouse                               0.008163
# IncidentGroup2_Assault                             -0.047980
# IncidentGroup2_Breaking_Enter                      -0.053134
# IncidentGroup2_Disorder                            -0.048238
# IncidentGroup2_Drugs                               -0.024796
# IncidentGroup2_Family_Offense                       1.000000
# IncidentGroup2_Property_Crime                      -0.075799
# IncidentGroup2_Robbery                             -0.018537
# IncidentGroup2_Theft                               -0.132438
# IncidentGroup2_Traffic                             -0.096894
# IncidentGroup2_Traffic_DUI                         -0.034143
#
#                                IncidentGroup2_Property_Crime  \
# Join_Count                                         -0.001404
# ZipCode2                                           -0.034779
# latitude                                            0.031303
# longitude                                          -0.028295
# hour_of_da                                          0.005127
# B25057e1                                           -0.020326
# B25058e1                                           -0.020996
# B25059e1                                           -0.026517
# B25076e1                                           -0.017251
# B25077e1                                           -0.015047
# B25078e1                                           -0.015011
# B25018e1                                            0.021038
# B25001e1                                           -0.050046
# B25002e1                                           -0.050046
# B25002e2                                           -0.048740
# B25002e3                                           -0.044733
# B19013e1                                           -0.022757
# MAX_TEMPERATUREF                                    0.004290
# PRECIPITATIONIN                                    -0.006937
# MEAN_VISIBILITYMILES                                0.011124
# TotalPoverty                                        0.006046
# Year                                                0.002634
# Month                                              -0.013045
# Day                                                 0.000424
# WeekNum                                             0.003482
# CityNum                                             0.067525
# WeatherEventNum                                    -0.006824
# ZoneNum                                             0.073256
# IncNum                                             -0.084598
# day_of_wee_Friday                                   0.006740
# ...                                                      ...
# CityName_CHAMBLEE                                  -0.001404
# CityName_DORAVILLE                                  0.008522
# CityName_DUNWOODY                                  -0.074260
# CityName_GCO                                       -0.001986
# CityName_SANDY SPRINGS                              0.075150
# weatherEventGroup_Fog                              -0.001489
# weatherEventGroup_Rain                             -0.008120
# weatherEventGroup_Snow                              0.006676
# ZoningGroup_                                       -0.063995
# ZoningGroup_Agriculture                             0.001938
# ZoningGroup_CUP                                     0.011275
# ZoningGroup_Commercial                             -0.026799
# ZoningGroup_Industrial                              0.007133
# ZoningGroup_MIX                                     0.006715
# ZoningGroup_Multi_Dwelling                          0.058416
# ZoningGroup_Multi_Family                            0.018140
# ZoningGroup_NUP                                    -0.000141
# ZoningGroup_Office                                  0.006205
# ZoningGroup_Single_Family                           0.037923
# ZoningGroup_Townhouse                               0.018150
# IncidentGroup2_Assault                             -0.107082
# IncidentGroup2_Breaking_Enter                      -0.118587
# IncidentGroup2_Disorder                            -0.107659
# IncidentGroup2_Drugs                               -0.055341
# IncidentGroup2_Family_Offense                      -0.075799
# IncidentGroup2_Property_Crime                       1.000000
# IncidentGroup2_Robbery                             -0.041371
# IncidentGroup2_Theft                               -0.295579
# IncidentGroup2_Traffic                             -0.216251
# IncidentGroup2_Traffic_DUI                         -0.076201
#
#                                IncidentGroup2_Robbery  IncidentGroup2_Theft  \
# Join_Count                                  -0.000343             -0.002454
# ZipCode2                                    -0.021489              0.116458
# latitude                                     0.016523             -0.084535
# longitude                                    0.002225              0.045891
# hour_of_da                                   0.010063              0.126853
# B25057e1                                    -0.004667              0.110509
# B25058e1                                    -0.008910              0.126421
# B25059e1                                    -0.009737              0.126821
# B25076e1                                    -0.030997              0.065240
# B25077e1                                    -0.028489              0.059273
# B25078e1                                    -0.028616              0.067248
# B25018e1                                    -0.013233             -0.075706
# B25001e1                                    -0.015439              0.200033
# B25002e1                                    -0.015439              0.200033
# B25002e2                                    -0.015538              0.199759
# B25002e3                                    -0.011394              0.155086
# B19013e1                                    -0.035513              0.075695
# MAX_TEMPERATUREF                            -0.007144             -0.010288
# PRECIPITATIONIN                              0.008782              0.025410
# MEAN_VISIBILITYMILES                        -0.002384             -0.015070
# TotalPoverty                                 0.039596             -0.028291
# Year                                        -0.014889              0.039780
# Month                                        0.004652              0.004122
# Day                                          0.003362             -0.034073
# WeekNum                                     -0.002658             -0.010303
# CityNum                                      0.017618             -0.164768
# WeatherEventNum                             -0.002471              0.031640
# ZoneNum                                      0.014932              0.044680
# IncNum                                       0.015158              0.353656
# day_of_wee_Friday                            0.001683             -0.005344
# ...                                               ...                   ...
# CityName_CHAMBLEE                           -0.000343             -0.002454
# CityName_DORAVILLE                           0.010304             -0.008085
# CityName_DUNWOODY                           -0.019004              0.164415
# CityName_GCO                                -0.000486              0.006720
# CityName_SANDY SPRINGS                       0.018414             -0.167395
# weatherEventGroup_Fog                        0.006066              0.005670
# weatherEventGroup_Rain                      -0.002122              0.030194
# weatherEventGroup_Snow                      -0.007718              0.000657
# ZoningGroup_                                -0.036712             -0.115492
# ZoningGroup_Agriculture                      0.000115              0.008054
# ZoningGroup_CUP                             -0.002307              0.003577
# ZoningGroup_Commercial                       0.017025              0.183090
# ZoningGroup_Industrial                       0.007107             -0.019938
# ZoningGroup_MIX                             -0.000642              0.038802
# ZoningGroup_Multi_Dwelling                   0.041922             -0.110839
# ZoningGroup_Multi_Family                     0.019219             -0.031628
# ZoningGroup_NUP                              0.010239             -0.000414
# ZoningGroup_Office                          -0.015246              0.062803
# ZoningGroup_Single_Family                   -0.019673              0.012669
# ZoningGroup_Townhouse                       -0.006461             -0.005510
# IncidentGroup2_Assault                      -0.026187             -0.187097
# IncidentGroup2_Breaking_Enter               -0.029001             -0.207198
# IncidentGroup2_Disorder                     -0.026328             -0.188104
# IncidentGroup2_Drugs                        -0.013534             -0.096694
# IncidentGroup2_Family_Offense               -0.018537             -0.132438
# IncidentGroup2_Property_Crime               -0.041371             -0.295579
# IncidentGroup2_Robbery                       1.000000             -0.072285
# IncidentGroup2_Theft                        -0.072285              1.000000
# IncidentGroup2_Traffic                      -0.052885             -0.377839
# IncidentGroup2_Traffic_DUI                  -0.018635             -0.133141
#
#                                IncidentGroup2_Traffic  \
# Join_Count                                  -0.001795
# ZipCode2                                    -0.070032
# latitude                                    -0.018459
# longitude                                   -0.065091
# hour_of_da                                  -0.018210
# B25057e1                                    -0.078501
# B25058e1                                    -0.059446
# B25059e1                                    -0.035436
# B25076e1                                     0.026741
# B25077e1                                     0.034975
# B25078e1                                     0.042294
# B25018e1                                     0.078644
# B25001e1                                    -0.103670
# B25002e1                                    -0.103670
# B25002e2                                    -0.105585
# B25002e3                                    -0.070514
# B19013e1                                     0.050958
# MAX_TEMPERATUREF                             0.000393
# PRECIPITATIONIN                             -0.007846
# MEAN_VISIBILITYMILES                         0.016602
# TotalPoverty                                -0.061718
# Year                                         0.002645
# Month                                       -0.004280
# Day                                         -0.009358
# WeekNum                                      0.009432
# CityNum                                      0.077174
# WeatherEventNum                             -0.019859
# ZoneNum                                     -0.254006
# IncNum                                       0.464516
# day_of_wee_Friday                            0.004584
# ...                                               ...
# CityName_CHAMBLEE                            0.006495
# CityName_DORAVILLE                          -0.008879
# CityName_DUNWOODY                           -0.072479
# CityName_GCO                                -0.002539
# CityName_SANDY SPRINGS                       0.074054
# weatherEventGroup_Fog                       -0.005881
# weatherEventGroup_Rain                      -0.019403
# weatherEventGroup_Snow                       0.003816
# ZoningGroup_                                 0.284452
# ZoningGroup_Agriculture                     -0.011429
# ZoningGroup_CUP                             -0.023329
# ZoningGroup_Commercial                      -0.044324
# ZoningGroup_Industrial                       0.018491
# ZoningGroup_MIX                             -0.032522
# ZoningGroup_Multi_Dwelling                  -0.128640
# ZoningGroup_Multi_Family                    -0.083623
# ZoningGroup_NUP                             -0.011121
# ZoningGroup_Office                          -0.054730
# ZoningGroup_Single_Family                   -0.085645
# ZoningGroup_Townhouse                       -0.029430
# IncidentGroup2_Assault                      -0.136883
# IncidentGroup2_Breaking_Enter               -0.151589
# IncidentGroup2_Disorder                     -0.137620
# IncidentGroup2_Drugs                        -0.070743
# IncidentGroup2_Family_Offense               -0.096894
# IncidentGroup2_Property_Crime               -0.216251
# IncidentGroup2_Robbery                      -0.052885
# IncidentGroup2_Theft                        -0.377839
# IncidentGroup2_Traffic                       1.000000
# IncidentGroup2_Traffic_DUI                  -0.097408
#
#                                IncidentGroup2_Traffic_DUI
# Join_Count                                      -0.000633
# ZipCode2                                         0.001019
# latitude                                        -0.025166
# longitude                                       -0.024321
# hour_of_da                                      -0.170185
# B25057e1                                        -0.040227
# B25058e1                                        -0.038576
# B25059e1                                        -0.031058
# B25076e1                                         0.020760
# B25077e1                                         0.031593
# B25078e1                                         0.032925
# B25018e1                                         0.047955
# B25001e1                                        -0.057063
# B25002e1                                        -0.057063
# B25002e2                                        -0.057446
# B25002e3                                        -0.042033
# B19013e1                                         0.030543
# MAX_TEMPERATUREF                                -0.008271
# PRECIPITATIONIN                                 -0.008641
# MEAN_VISIBILITYMILES                             0.000499
# TotalPoverty                                    -0.022230
# Year                                            -0.023057
# Month                                           -0.004350
# Day                                              0.098824
# WeekNum                                          0.014537
# CityNum                                          0.018675
# WeatherEventNum                                 -0.016422
# ZoneNum                                         -0.126310
# IncNum                                           0.237580
# day_of_wee_Friday                                0.001980
# ...                                                   ...
# CityName_CHAMBLEE                               -0.000633
# CityName_DORAVILLE                              -0.005944
# CityName_DUNWOODY                               -0.016782
# CityName_GCO                                    -0.000895
# CityName_SANDY SPRINGS                           0.017899
# weatherEventGroup_Fog                            0.003243
# weatherEventGroup_Rain                          -0.016764
# weatherEventGroup_Snow                          -0.002269
# ZoningGroup_                                     0.145935
# ZoningGroup_Agriculture                         -0.004744
# ZoningGroup_CUP                                 -0.008776
# ZoningGroup_Commercial                          -0.032263
# ZoningGroup_Industrial                           0.008326
# ZoningGroup_MIX                                 -0.023491
# ZoningGroup_Multi_Dwelling                      -0.058955
# ZoningGroup_Multi_Family                        -0.037512
# ZoningGroup_NUP                                 -0.000218
# ZoningGroup_Office                              -0.041459
# ZoningGroup_Single_Family                       -0.027377
# ZoningGroup_Townhouse                           -0.009221
# IncidentGroup2_Assault                          -0.048234
# IncidentGroup2_Breaking_Enter                   -0.053416
# IncidentGroup2_Disorder                         -0.048494
# IncidentGroup2_Drugs                            -0.024928
# IncidentGroup2_Family_Offense                   -0.034143
# IncidentGroup2_Property_Crime                   -0.076201
# IncidentGroup2_Robbery                          -0.018635
# IncidentGroup2_Theft                            -0.133141
# IncidentGroup2_Traffic                          -0.097408
# IncidentGroup2_Traffic_DUI                       1.000000
#
# [67 rows x 67 columns]

# %% [markdown]
# ## Test - Train Split the Data

# %%
cols = dfMCats.columns
for i, cols in enumerate(cols):
    print(i, cols)
# Out:
# (0, 'Join_Count')
# (1, 'ZipCode2')
# (2, 'latitude')
# (3, 'longitude')
# (4, 'hour_of_da')
# (5, 'B25057e1')
# (6, 'B25058e1')
# (7, 'B25059e1')
# (8, 'B25076e1')
# (9, 'B25077e1')
# (10, 'B25078e1')
# (11, 'B25018e1')
# (12, 'B25001e1')
# (13, 'B25002e1')
# (14, 'B25002e2')
# (15, 'B25002e3')
# (16, 'B19013e1')
# (17, 'MAX_TEMPERATUREF')
# (18, 'PRECIPITATIONIN')
# (19, 'MEAN_VISIBILITYMILES')
# (20, 'TotalPoverty')
# (21, 'Year')
# (22, 'Month')
# (23, 'Day')
# (24, 'WeekNum')
# (25, 'CityNum')
# (26, 'WeatherEventNum')
# (27, 'ZoneNum')
# (28, 'IncNum')
# (29, 'day_of_wee_Friday')
# (30, 'day_of_wee_Monday')
# (31, 'day_of_wee_Saturday')
# (32, 'day_of_wee_Sunday')
# (33, 'day_of_wee_Thursday')
# (34, 'day_of_wee_Tuesday')
# (35, 'day_of_wee_Wednesday')
# (36, 'CityName_ATLANTA')
# (37, 'CityName_CHAMBLEE')
# (38, 'CityName_DORAVILLE')
# (39, 'CityName_DUNWOODY')
# (40, 'CityName_GCO')
# (41, 'CityName_SANDY SPRINGS')
# (42, 'weatherEventGroup_Fog')
# (43, 'weatherEventGroup_Rain')
# (44, 'weatherEventGroup_Snow')
# (45, 'ZoningGroup_ ')
# (46, 'ZoningGroup_Agriculture')
# (47, 'ZoningGroup_CUP')
# (48, 'ZoningGroup_Commercial')
# (49, 'ZoningGroup_Industrial')
# (50, 'ZoningGroup_MIX')
# (51, 'ZoningGroup_Multi_Dwelling')
# (52, 'ZoningGroup_Multi_Family')
# (53, 'ZoningGroup_NUP')
# (54, 'ZoningGroup_Office')
# (55, 'ZoningGroup_Single_Family')
# (56, 'ZoningGroup_Townhouse')
# (57, 'IncidentGroup2_Assault')
# (58, 'IncidentGroup2_Breaking_Enter')
# (59, 'IncidentGroup2_Disorder')
# (60, 'IncidentGroup2_Drugs')
# (61, 'IncidentGroup2_Family_Offense')
# (62, 'IncidentGroup2_Property_Crime')
# (63, 'IncidentGroup2_Robbery')
# (64, 'IncidentGroup2_Theft')
# (65, 'IncidentGroup2_Traffic')
# (66, 'IncidentGroup2_Traffic_DUI')

# %%
dfMCats.IncNum.dtypes
# Out:
# dtype('int64')

# %%
X_train = X
X_train.shape
# Out:
# (85761, 56)

# %%
print yAssault.shape
print X_train.shape
print yBreak_Enter.shape
print X.shape
print y.shape
print "y_test_Assault", y_test_Assault.shape
print "y_train_Assault", y_train_Assault.shape
print dfMCats.shape
print dfMCats.IncidentGroup2_Assault.value_counts()
# Out:
# (85761L,)
# (64320, 56)
# (85761L,)
# (85761, 56)
# (85761L,)
# y_test_Assault (21441L,)
# y_train_Assault (64320L,)
# (85761, 67)
# 0.0    80317
# 1.0     5444
# Name: IncidentGroup2_Assault, dtype: int64

# %%
from sklearn.cross_validation import train_test_split
X = dfMCats[dfMCats.columns[1:57]]
# hmm yes this is a problem "IncNum" Column is a target and predictor....
y = dfMCats.IncNum
yAssault = dfMCats.IncidentGroup2_Assault
yBreak_Enter = dfMCats.IncidentGroup2_Breaking_Enter
yDisorder = dfMCats.IncidentGroup2_Disorder
yDrugs = dfMCats.IncidentGroup2_Drugs
yFamilyOff = dfMCats.IncidentGroup2_Family_Offense
yPropCrime = dfMCats.IncidentGroup2_Property_Crime
yRobbery = dfMCats.IncidentGroup2_Robbery
yTheft = dfMCats.IncidentGroup2_Theft
yTraffic = dfMCats.IncidentGroup2_Traffic
yDUI = dfMCats.IncidentGroup2_Traffic_DUI
# ****
# there has to be a better way!!!
# ****
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
X_train, X_test, y_train_Assault, y_test_Assault = train_test_split(X, yAssault, random_state=0)
X_train, X_test, y_train_BreakEnter, y_test_BreakEnter = train_test_split(X, yBreak_Enter, random_state=0)
X_train, X_test, y_train_Disorder, y_test_Disorder = train_test_split(X, yDisorder, random_state=0)
X_train, X_test, y_train_Drugs, y_test_Drugs = train_test_split(X, yDrugs, random_state=0)
X_train, X_test, y_train_FamOffense, y_test_FamOffense = train_test_split(X, yFamilyOff, random_state=0)
X_train, X_test, y_train_PropCrime, y_test_PropCrime = train_test_split(X, yPropCrime, random_state=0)
X_train, X_test, y_train_Robbery, y_test_Robbery = train_test_split(X, yRobbery, random_state=0)
X_train, X_test, y_train_Theft, y_test_Theft = train_test_split(X, yTheft, random_state=0)
X_train, X_test, y_train_Traffic, y_test_Traffic = train_test_split(X, yTraffic, random_state=0)
X_train, X_test, y_train_DUI, y_test_DUI = train_test_split(X, yDUI, random_state=0)

# %%
X.columns
# Out:
# Index([u'ZipCode2', u'latitude', u'longitude', u'hour_of_da', u'B25057e1',
#        u'B25058e1', u'B25059e1', u'B25076e1', u'B25077e1', u'B25078e1',
#        u'B25018e1', u'B25001e1', u'B25002e1', u'B25002e2', u'B25002e3',
#        u'B19013e1', u'MAX_TEMPERATUREF', u'PRECIPITATIONIN',
#        u'MEAN_VISIBILITYMILES', u'TotalPoverty', u'Year', u'Month', u'Day',
#        u'WeekNum', u'CityNum', u'WeatherEventNum', u'ZoneNum', u'IncNum',
#        u'day_of_wee_Friday', u'day_of_wee_Monday', u'day_of_wee_Saturday',
#        u'day_of_wee_Sunday', u'day_of_wee_Thursday', u'day_of_wee_Tuesday',
#        u'day_of_wee_Wednesday', u'CityName_ATLANTA', u'CityName_CHAMBLEE',
#        u'CityName_DORAVILLE', u'CityName_DUNWOODY', u'CityName_GCO',
#        u'CityName_SANDY SPRINGS', u'weatherEventGroup_Fog',
#        u'weatherEventGroup_Rain', u'weatherEventGroup_Snow', u'ZoningGroup_ ',
#        u'ZoningGroup_Agriculture', u'ZoningGroup_CUP',
#        u'ZoningGroup_Commercial', u'ZoningGroup_Industrial',
#        u'ZoningGroup_MIX', u'ZoningGroup_Multi_Dwelling',
#        u'ZoningGroup_Multi_Family', u'ZoningGroup_NUP', u'ZoningGroup_Office',
#        u'ZoningGroup_Single_Family', u'ZoningGroup_Townhouse'],
#       dtype='object')

# %% [markdown]
# ### Here it goes - finally, the fun part - fitting data to Random Forest Classification
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html<br/>
# http://scikit-learn.org/stable/modules/multiclass.html<br/>
# http://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.LabelEncoder.html <br/>
# http://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.OneHotEncoder.html#sklearn.preprocessing.OneHotEncoder <br/>
# http://stackoverflow.com/questions/24458645/label-encoding-across-multiple-columns-in-scikit-learn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Magic with the DecisionTree, do voodoo (magic)
# I'm cookin, I'm cookin, in the kitchen with pots and pans

# %%
dfMCats.head(10)
# Out:
#                      Join_Count  ZipCode2   latitude  longitude  hour_of_da  \
# Date
# 2010-01-01 00:00:00           1         0  33.965092 -84.314529           0
# 2010-01-01 00:00:00           1         0  33.965092 -84.314529           0
# 2010-01-01 00:00:00           1         0  33.965092 -84.314529           0
# 2010-01-01 00:00:00           1         0  33.919469 -84.359070           0
# 2010-01-01 00:00:00           1         0  33.919469 -84.359070           0
# 2010-01-01 00:00:00           1         0  33.919469 -84.359070           0
# 2010-01-01 00:00:00           1         0  33.916951 -84.435593           0
# 2010-01-01 00:00:00           1         0  33.916951 -84.435593           0
# 2010-01-01 00:00:00           1         0  33.916951 -84.435593           0
# 2010-01-01 00:01:00           1         0  33.952381 -84.342235           0
#
#                      B25057e1  B25058e1  B25059e1  B25076e1  B25077e1  \
# Date
# 2010-01-01 00:00:00     683.0     741.5    1000.5  403250.0  507400.0
# 2010-01-01 00:00:00     683.0     741.5    1000.5  403250.0  507400.0
# 2010-01-01 00:00:00     683.0     741.5    1000.5  403250.0  507400.0
# 2010-01-01 00:00:00     834.0    1115.5    1315.5  159500.0  226500.0
# 2010-01-01 00:00:00     834.0    1115.5    1315.5  159500.0  226500.0
# 2010-01-01 00:00:00     834.0    1115.5    1315.5  159500.0  226500.0
# 2010-01-01 00:00:00       0.0       0.0       0.0  546700.0  710600.0
# 2010-01-01 00:00:00       0.0       0.0       0.0  546700.0  710600.0
# 2010-01-01 00:00:00       0.0       0.0       0.0  546700.0  710600.0
# 2010-01-01 00:01:00       0.0       0.0       0.0  418800.0  508300.0
#
#                                 ...              IncidentGroup2_Assault  \
# Date                            ...
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:00:00             ...                                 0.0
# 2010-01-01 00:01:00             ...                                 0.0
#
#                      IncidentGroup2_Breaking_Enter  IncidentGroup2_Disorder  \
# Date
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      1.0
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      1.0
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      0.0
# 2010-01-01 00:00:00                            0.0                      1.0
# 2010-01-01 00:01:00                            0.0                      0.0
#
#                      IncidentGroup2_Drugs  IncidentGroup2_Family_Offense  \
# Date
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:00:00                   0.0                            0.0
# 2010-01-01 00:01:00                   0.0                            0.0
#
#                      IncidentGroup2_Property_Crime  IncidentGroup2_Robbery  \
# Date
# 2010-01-01 00:00:00                            1.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:00:00                            1.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:00:00                            1.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:00:00                            0.0                     0.0
# 2010-01-01 00:01:00                            1.0                     0.0
#
#                      IncidentGroup2_Theft  IncidentGroup2_Traffic  \
# Date
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:00:00                   1.0                     0.0
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:00:00                   1.0                     0.0
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:00:00                   1.0                     0.0
# 2010-01-01 00:00:00                   0.0                     0.0
# 2010-01-01 00:01:00                   0.0                     0.0
#
#                      IncidentGroup2_Traffic_DUI
# Date
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:00:00                         0.0
# 2010-01-01 00:01:00                         0.0
#
# [10 rows x 67 columns]

# %% [markdown]
# * X = dfMCats[dfMCats.columns[1:59]]
#
# * y = dfMCats.IncNum
# * yAssault = dfMCats.IncidentGroup2_Assault
# * yBreak_Enter = dfMCats.IncidentGroup2_Breaking_Enter
# * yDisorder = dfMCats.IncidentGroup2_Disorder
# * yDrugs = dfMCats.IncidentGroup2_Drugs
# * yFamilyOff = dfMCats.IncidentGroup2_Family_Offense
# * yPropCrime = dfMCats.IncidentGroup2_Property_Crime
# * yRobbery = dfMCats.IncidentGroup2_Robbery
# * yTheft = dfMCats.IncidentGroup2_Theft
# * yTraffic = dfMCats.IncidentGroup2_Traffic
# * yDUI = dfMCats.IncidentGroup2_Traffic_DUI

# %%
# Fit Decision Tree
modelDT = DecisionTreeClassifier()
modelDT_Assault = DecisionTreeClassifier()
modelDT_BreakEnter = DecisionTreeClassifier()
modelDT_Disorder =DecisionTreeClassifier()
modelDT_Drugs = DecisionTreeClassifier()
modelDT_FamOff = DecisionTreeClassifier()
modelDT_PropCrime = DecisionTreeClassifier()
modelDT_Robbery = DecisionTreeClassifier()
modelDT_Theft = DecisionTreeClassifier()
modelDT_Traffic = DecisionTreeClassifier()
modelDT_DUI = DecisionTreeClassifier()

modelDT.fit(X_train, y_train).predict(X_test)
modelDT_Assault.fit(X_train, y_train_Assault).predict(X_test)
modelDT_BreakEnter.fit(X_train, y_train_BreakEnter).predict(X_test)
modelDT_Disorder.fit(X_train, y_train_Disorder).predict(X_test)
modelDT_Drugs.fit(X_train, y_train_Drugs).predict(X_test)
modelDT_FamOff.fit(X_train, y_train_FamOffense).predict(X_test)
modelDT_PropCrime.fit(X_train, y_train_PropCrime).predict(X_test)
modelDT_Robbery.fit(X_train, y_train_Robbery).predict(X_test)
modelDT_Theft.fit(X_train, y_train_Theft).predict(X_test)
modelDT_Traffic.fit(X_train, y_train_Traffic).predict(X_test)
modelDT_DUI.fit(X_train, y_train_DUI).predict(X_test)
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
Preds = X.columns.tolist()

# %%
FI = modelDT.feature_importances_
FI_Assault = modelDT_Assault.feature_importances_
FI_BreakEnter = modelDT_BreakEnter.feature_importances_ 
FI_Disorder = modelDT_Disorder.feature_importances_
FI_Drugs = modelDT_Drugs.feature_importances_
FI_FamOff = modelDT_FamOff.feature_importances_
FI_PropCrime = modelDT_PropCrime.feature_importances_
FI_Robbery = modelDT_Robbery.feature_importances_
FI_Theft = modelDT_Theft.feature_importances_
FI_Traffic = modelDT_Traffic.feature_importances_
FI_DUI = modelDT_DUI.feature_importances_


dic = {"Predictors": pd.Series(Preds), "Assault": pd.Series(FI_Assault), "BreakEnter" : pd.Series(FI_BreakEnter),
      "Disorder": pd.Series(FI_Disorder), "Drugs": pd.Series(FI_Drugs), "FamilyOffense" : pd.Series(FI_FamOff),
      "PropertyCrime": pd.Series(FI_PropCrime), "Robbery" : pd.Series(FI_Robbery), "Theft" : pd.Series(FI_Theft),
      "Traffic": pd.Series(FI_Traffic), "DUI": pd.Series(FI_DUI)
      }

FIdf = pd.DataFrame(dic)
FIdf.set_index('Predictors', inplace = True)
FIdf
# Out:
#                              Assault  BreakEnter       DUI  Disorder  \
# Predictors
# ZipCode2                    0.000509    0.000984  0.000000  0.000003
# ZoningGroup_NUP             0.000000  0.000000
# ZoningGroup_Office          0.002039  0.001015
# ZoningGroup_Single_Family   0.001405  0.000465
# ZoningGroup_Townhouse       0.000523  0.000000

# %% [markdown]
# ```
# ----------
# estimators_ : list of DecisionTreeClassifier
#     The collection of fitted sub-estimators.
#
# classes_ : array of shape = [n_classes] or a list of such arrays
#     The classes labels (single output problem), or a list of arrays of
#     class labels (multi-output problem).
#
# n_classes_ : int or list
#     The number of classes (single output problem), or a list containing the
#     number of classes for each output (multi-output problem).
#
# n_features_ : int
#     The number of features when ``fit`` is performed.
#
# n_outputs_ : int
#     The number of outputs when ``fit`` is performed.
#
# feature_importances_ : array of shape = [n_features]
#     The feature importances (the higher, the more important the feature).
#
# oob_score_ : float
#     Score of the training dataset obtained using an out-of-bag estimate.
#
# oob_decision_function_ : array of shape = [n_samples, n_classes]
#     Decision function computed with out-of-bag estimate on the training
#     set. If n_estimators is small it might be possible that a data point
#     was never left out during the bootstrap. In this case,
#     `oob_decision_function_` might contain NaN.
#
# References
# ----------
#
# .. [1] L. Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.
# ```

# %%
modelRF = RandomForestClassifier(n_estimators = 1)
modelRF_Assault = RandomForestClassifier(n_estimators = 1)
modelRF_BreakEnter = RandomForestClassifier(n_estimators = 1)
modelRF_Disorder = RandomForestClassifier(n_estimators = 1)
modelRF_Drugs = RandomForestClassifier(n_estimators = 1)
modelRF_FamOff = RandomForestClassifier(n_estimators = 1)
modelRF_PropCrime = RandomForestClassifier(n_estimators = 1)
modelRF_Robbery = RandomForestClassifier(n_estimators = 1)
modelRF_Theft = RandomForestClassifier(n_estimators = 1)
modelRF_Traffic = RandomForestClassifier(n_estimators = 1)
modelRF_DUI = RandomForestClassifier(n_estimators = 1)

modelRF.fit(X_train, y_train).predict(X_test)
modelRF_Assault.fit(X_train, y_train_Assault).predict(X_test)
modelRF_BreakEnter.fit(X_train, y_train_BreakEnter).predict(X_test)
modelRF_Disorder.fit(X_train, y_train_Disorder).predict(X_test)
modelRF_Drugs.fit(X_train, y_train_Drugs).predict(X_test)
modelRF_FamOff.fit(X_train, y_train_FamOffense).predict(X_test)
modelRF_PropCrime.fit(X_train, y_train_PropCrime).predict(X_test)
modelRF_Robbery.fit(X_train, y_train_Robbery).predict(X_test)
modelRF_Theft.fit(X_train, y_train_Theft).predict(X_test)
modelRF_Traffic.fit(X_train, y_train_Traffic).predict(X_test)
modelRF_DUI.fit(X_train, y_train_DUI).predict(X_test)
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
FIRF = modelDT.feature_importances_
FIRF_Assault = modelRF_Assault.feature_importances_
FIRF_BreakEnter = modelRF_BreakEnter.feature_importances_ 
FIRF_Disorder = modelRF_Disorder.feature_importances_
FIRF_Drugs = modelRF_Drugs.feature_importances_
FIRF_FamOff = modelRF_FamOff.feature_importances_
FIRF_PropCrime = modelRF_PropCrime.feature_importances_
FIRF_Robbery = modelRF_Robbery.feature_importances_
FIRF_Theft = modelRF_Theft.feature_importances_
FIRF_Traffic = modelRF_Traffic.feature_importances_
FIRF_DUI = modelRF_DUI.feature_importances_

dic = {"Predictors": pd.Series(Preds),"All": pd.Series(FIRF), "Assault": pd.Series(FIRF_Assault), "BreakEnter" : pd.Series(FIRF_BreakEnter),
      "Disorder": pd.Series(FIRF_Disorder), "Drugs": pd.Series(FIRF_Drugs), "FamilyOffense" : pd.Series(FIRF_FamOff),
      "PropertyCrime": pd.Series(FIRF_PropCrime), "Robbery" : pd.Series(FIRF_Robbery), "Theft" : pd.Series(FIRF_Theft),
      "Traffic": pd.Series(FIRF_Traffic), "DUI": pd.Series(FIRF_DUI)
      }
FIRFdf = pd.DataFrame(dic)
FIRFdf.set_index('Predictors', inplace = True)
FIRFdf
# Out:
#                             All   Assault  BreakEnter       DUI  Disorder  \
# Predictors
# ZipCode2                    0.0  0.004460    0.006745  0.004264  0.002233
# latitude                    0.0  0.019325    0.024654  0.008468  0.013276
# longitude                   0.0  0.027798    0.021934  0.012431  0.016082
# hour_of_da                  0.0  0.025636    0.041816  0.115305  0.016701
# B25057e1                    0.0  0.003441    0.003821  0.001547  0.004659
# B25058e1                    0.0  0.003906    0.006304  0.002227  0.006368
# B25059e1                    0.0  0.010003    0.006492  0.003852  0.002663
# B25076e1                    0.0  0.002986    0.003773  0.002091  0.006706
# B25077e1                    0.0  0.002618    0.005566  0.005060  0.003236
# B25078e1                    0.0  0.004538    0.008499  0.004552  0.008937
# B25018e1                    0.0  0.003202    0.004103  0.002802  0.004256
# B25001e1                    0.0  0.004296    0.011488  0.010243  0.002621
# B25002e1                    0.0  0.003361    0.007627  0.002671  0.002377
# B25002e2                    0.0  0.002159    0.005577  0.004574  0.004435
# B25002e3                    0.0  0.002464    0.007327  0.002151  0.002493
# B19013e1                    0.0  0.004003    0.011633  0.002190  0.003739
# MAX_TEMPERATUREF            0.0  0.023508    0.020894  0.009310  0.014180
# PRECIPITATIONIN             0.0  0.011464    0.007909  0.005269  0.008597
# MEAN_VISIBILITYMILES        0.0  0.010240    0.013513  0.002952  0.005624
# TotalPoverty                0.0  0.002890    0.003515  0.001393  0.004392
# Year                        0.0  0.009167    0.013643  0.005188  0.015191
# Month                       0.0  0.014477    0.018033  0.007630  0.012680
# Day                         0.0  0.008934    0.006795  0.016004  0.005366
# WeekNum                     0.0  0.007579    0.009887  0.004945  0.006897
# CityNum                     0.0  0.002622    0.002052  0.000442  0.005452
# WeatherEventNum             0.0  0.002783    0.005161  0.002892  0.003420
# ZoneNum                     0.0  0.015468    0.033097  0.008425  0.009025
# IncNum                      1.0  0.725243    0.626161  0.727466  0.764414
# day_of_wee_Friday           0.0  0.001522    0.002424  0.000945  0.001684
# day_of_wee_Monday           0.0  0.001050    0.003126  0.000522  0.001712
# day_of_wee_Saturday         0.0  0.001146    0.000975  0.000991  0.001809
# day_of_wee_Sunday           0.0  0.001961    0.003660  0.000384  0.001176
# day_of_wee_Thursday         0.0  0.002370    0.004930  0.000832  0.002123
# day_of_wee_Tuesday          0.0  0.001753    0.004167  0.000059  0.001602
# CityNum                     0.004795  0.002625
# WeatherEventNum             0.001065  0.002578
# ZoneNum                     0.005427  0.003682
# IncNum                      0.875539  0.738452
# day_of_wee_Friday           0.001028  0.001927
# day_of_wee_Monday           0.000975  0.000849
# day_of_wee_Saturday         0.000920  0.001160
# day_of_wee_Sunday           0.000142  0.000622
# day_of_wee_Thursday         0.001092  0.001881
# day_of_wee_Tuesday          0.000931  0.001740
# day_of_wee_Wednesday        0.000710  0.001071
# CityName_ATLANTA            0.000139  0.000278
# CityName_CHAMBLEE           0.000000  0.000000
# CityName_DORAVILLE          0.000249  0.000169
# CityName_DUNWOODY           0.002264  0.002211
# CityName_GCO                0.000000  0.000000
# CityName_SANDY SPRINGS      0.003365  0.003643
# weatherEventGroup_Fog       0.000234  0.001266
# weatherEventGroup_Rain      0.000680  0.002108
# weatherEventGroup_Snow      0.000017  0.000239
# ZoningGroup_                0.003983  0.011786
# ZoningGroup_Agriculture     0.000057  0.000543
# ZoningGroup_CUP             0.000305  0.000214
# ZoningGroup_Commercial      0.002519  0.002768
# ZoningGroup_Industrial      0.000000  0.000000
# ZoningGroup_MIX             0.000585  0.000279
# ZoningGroup_Multi_Dwelling  0.003057  0.001045
# ZoningGroup_Multi_Family    0.002100  0.001471
# ZoningGroup_NUP             0.000000  0.000000
# ZoningGroup_Office          0.003275  0.001678
# ZoningGroup_Single_Family   0.001474  0.000977
# ZoningGroup_Townhouse       0.000201  0.000059

# %%
FIRFdf.shape
# Out:
# (56, 11)

# %%
ZoneSection = FIRFdf.iloc[44:56]
ZoneSection
# Out:
#                             All   Assault  BreakEnter       DUI  Disorder  \
# Predictors
# ZoningGroup_                0.0  0.004961    0.006213  0.013771  0.010016
# ZoningGroup_Agriculture     0.0  0.000000    0.000193  0.000000  0.000000
# ZoningGroup_CUP             0.0  0.000358    0.000097  0.000059  0.000255
# ZoningGroup_Commercial      0.0  0.006261    0.004289  0.000785  0.001031
# ZoningGroup_Industrial      0.0  0.000000    0.000000  0.000000  0.000000
# ZoningGroup_MIX             0.0  0.001941    0.001214  0.000000  0.000000
# ZoningGroup_Multi_Dwelling  0.0  0.002684    0.001933  0.000042  0.001907
# ZoningGroup_Multi_Family    0.0  0.003159    0.006214  0.000000  0.000861
# ZoningGroup_NUP             0.0  0.000000    0.000000  0.000000  0.000000
# ZoningGroup_Office          0.0  0.002695    0.004570  0.000066  0.001767
# ZoningGroup_Single_Family   0.0  0.000789    0.003163  0.000044  0.000653
# ZoningGroup_Townhouse       0.0  0.000000    0.000895  0.000061  0.000041
#
#                                Drugs  FamilyOffense  PropertyCrime   Robbery  \
# Predictors
# ZoningGroup_                0.001521       0.002546       0.006816  0.001989
# ZoningGroup_Agriculture     0.000000       0.000000       0.000000  0.000000
# ZoningGroup_CUP             0.001127       0.001643       0.001028  0.000023
# ZoningGroup_Commercial      0.002057       0.005493       0.005444  0.004702
# ZoningGroup_Industrial      0.000000       0.000000       0.000000  0.000000
# ZoningGroup_MIX             0.001165       0.000040       0.001088  0.000482
# ZoningGroup_Multi_Dwelling  0.007298       0.002111       0.003653  0.007592
# ZoningGroup_Multi_Family    0.000802       0.005018       0.003967  0.002341
# ZoningGroup_NUP             0.000000       0.000000       0.000094  0.000175
# ZoningGroup_Office          0.000325       0.006309       0.003723  0.000421
# ZoningGroup_Single_Family   0.000601       0.006840       0.001569  0.001062
# ZoningGroup_Townhouse       0.000042       0.002246       0.000592  0.000212
#
#                                Theft   Traffic
# Predictors
# ZoningGroup_                0.003983  0.011786
# ZoningGroup_Agriculture     0.000057  0.000543
# ZoningGroup_CUP             0.000305  0.000214
# ZoningGroup_Commercial      0.002519  0.002768
# ZoningGroup_Industrial      0.000000  0.000000
# ZoningGroup_MIX             0.000585  0.000279
# ZoningGroup_Multi_Dwelling  0.003057  0.001045
# ZoningGroup_Multi_Family    0.002100  0.001471
# ZoningGroup_NUP             0.000000  0.000000
# ZoningGroup_Office          0.003275  0.001678
# ZoningGroup_Single_Family   0.001474  0.000977
# ZoningGroup_Townhouse       0.000201  0.000059

# %% [markdown]
# ## Difference between Frequency of an Event and Model Feature Importance of an Event

# %% [markdown]
# `kind : {``point``, ``bar``, ``count``, ``box``, ``violin``, ``strip``}`

# %%
sb.factorplot(x = "ZoneNum", y = "IncidentGroup2_Assault", data = dfMCats, kind = "bar", size = 12, aspect =2)
ZoneNum
# Out:
# {' ': 0,
#  'Agriculture': 1,
#  'CUP': 2,
#  'Commercial': 3,
#  'Industrial': 4,
#  'MIX': 5,
#  'Multi_Dwelling': 6,
#  'Multi_Family': 7,
#  'NUP': 8,
#  'Office': 9,
#  'Single_Family': 10,
#  'Townhouse': 11}

# %%
sb.factorplot(x= ZoneSection.index, y="Disorder", data=ZoneSection, kind="bar", size=12, aspect=2)

# %%
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, confusion_matrix
from sklearn import metrics

# %%
print dfMCats.IncidentGroup2_Assault.value_counts()
print dfMCats['IncidentGroup2_Assault'].shape
print y_test_Assault.shape
# Out:
# 0.0    80317
# 1.0     5444
# Name: IncidentGroup2_Assault, dtype: int64
# (85761L,)
# (21441L,)

# %%
y_pred_Assault = modelRF_Assault.fit(X_train, y_train_Assault).predict(X_test)
y_pred_Assault
y_pred_Assault.shape
# Out:
# (21441L,)

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(confusion_matrix(y_test_Assault, y_pred_Assault), cmap=plt.cm.binary)
plt.title('Confusion Martix Assault Prediction')
plt.colorbar()
plt.ylabel("Expected")
plt.xlabel("Predicted")

matrix = confusion_matrix(y_test_Assault, y_pred_Assault)
matrix
# Out:
# array([[19932,   210],
#        [  192,  1107]])

# %%
print metrics.classification_report(y_test_Assault, y_pred_Assault)
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99     20142
#         1.0       0.84      0.85      0.85      1299
#
# avg / total       0.98      0.98      0.98     21441

# %%
print metrics.accuracy_score(y_test_Assault, y_pred_Assault)
# Out:
# 0.981250874493

# %%
ax = plt.subplot(111)
val = metrics.roc_curve(y_test_Assault, y_pred_Assault)

ax.plot(val[0], val[1])
ax.set(title = "ROC")

# %% [markdown]
# Impossible
